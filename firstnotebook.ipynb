# %%
import matplotlib.pyplot as plt
import numpy as np
print("Hello World")
# Out:
# Hello World

# %% [markdown]
# # Bar Graph

# %%
bar_labels = ['A','B','C','D','E']
bar_heights = [5, 9, 1, 2, 1]

plt.bar(bar_labels, bar_heights)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# # Line Graph

# %%
x = [2,9,4,3,7,1,5,2,5,3,2,1,5,6,7,3,7,8,3,2] #list of numbers
y = [2,7,3,3,3,2,5,6,3,5,7,6,3,2,7,7,4,2,1,2] #List of other numbers

plt.scatter(x,y)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
